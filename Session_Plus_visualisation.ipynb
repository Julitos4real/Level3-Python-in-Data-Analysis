# %%
import pandas as pd

# %%
#read in the csv file
df = pd.read_csv('/content/pandas data.csv')

df
# Out:
#      Distance  Pulse  Maxpulse  Calories
# 0        60.0    110       130     409.1
# 1        60.0    117       145     479.0
# 2        60.0    103       135     340.0
# 3        45.0    109       175     282.4
# 4        45.0    117       148     406.0
# ..        ...    ...       ...       ...
# 164      60.0    105       140     290.8
# 165      60.0    110       145     300.0
# 166      60.0    115       145     310.2
# 167      75.0    120       150     320.4
# 168      75.0    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.head(15)
# Out:
#     Distance  Pulse  Maxpulse  Calories
# 0       60.0    110       130     409.1
# 1       60.0    117       145     479.0
# 2       60.0    103       135     340.0
# 3       45.0    109       175     282.4
# 4       45.0    117       148     406.0
# 5       60.0    102       127     300.0
# 6       60.0    110       136     374.0
# 7       45.0    104       134     253.3
# 8       30.0    109       133     195.1
# 9       60.0     98       124     269.0
# 10      60.0    103       147     329.3
# 11      60.0    100       120     250.7
# 12      60.0    106       128     345.3
# 13      60.0    104       132     379.3
# 14      60.0     98       123     275.0

# %%
df.tail(10)
# Out:
#      Distance  Pulse  Maxpulse  Calories
# 159      30.0     80       120     240.9
# 160      30.0     85       120     250.4
# 161      45.0     90       130     260.4
# 162      45.0     95       130     270.0
# 163      45.0    100       140     280.9
# 164      60.0    105       140     290.8
# 165      60.0    110       145     300.0
# 166      60.0    115       145     310.2
# 167      75.0    120       150     320.4
# 168      75.0    125       150     330.4

# %%
# Store data in a variable

df = pd.read_csv('/content/pandas data.csv')

# %%
df.head(10)
# Out:
#    Distance  Pulse  Maxpulse  Calories
# 0      60.0    110       130     409.1
# 1      60.0    117       145     479.0
# 2      60.0    103       135     340.0
# 3      45.0    109       175     282.4
# 4      45.0    117       148     406.0
# 5      60.0    102       127     300.0
# 6      60.0    110       136     374.0
# 7      45.0    104       134     253.3
# 8      30.0    109       133     195.1
# 9      60.0     98       124     269.0

# %%
df.tail(10)
# Out:
#      Distance  Pulse  Maxpulse  Calories
# 159      30.0     80       120     240.9
# 160      30.0     85       120     250.4
# 161      45.0     90       130     260.4
# 162      45.0     95       130     270.0
# 163      45.0    100       140     280.9
# 164      60.0    105       140     290.8
# 165      60.0    110       145     300.0
# 166      60.0    115       145     310.2
# 167      75.0    120       150     320.4
# 168      75.0    125       150     330.4

# %%
df.shape
# Out:
# (169, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Distance  164 non-null    float64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 5.4 KB

# %%
df.columns
# Out:
# Index(['Distance', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.describe()
# Out:
#          Distance       Pulse    Maxpulse     Calories
# count  164.000000  169.000000  169.000000   164.000000
# mean    64.420732  107.461538  134.047337   375.790244
# std     42.780648   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df.isnull().any()
# Out:
# Distance     True
# Pulse       False
# Maxpulse    False
# Calories     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Distance    5
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df['Distance'].unique()
# Out:
# array([ 60.,  45.,  30.,  nan,  80.,  20., 210., 160., 180., 150., 300.,
#         90., 120., 270.,  15.,  25.,  75.])

# %%
df['Distance'].unique()
# Out:
# array([ 60.,  45.,  30.,  nan,  80.,  20., 210., 160., 180., 150., 300.,
#         90., 120., 270.,  15.,  25.,  75.])

# %%
df['Maxpulse'].unique()
# Out:
# array([130, 145, 135, 175, 148, 127, 136, 134, 133, 124, 147, 120, 128,
#        132, 123, 112, 125, 131, 119, 101, 126, 118, 129, 115, 113, 140,
#        122, 138, 153, 139, 146, 151, 121, 144, 172, 152, 160, 137, 141,
#        143, 182, 169, 170, 157, 103, 107, 100, 171, 168, 110, 108, 184,
#        156, 162, 149, 150, 167])

# %%
df['Calories'].unique()
# Out:
# array([ 409.1,  479. ,  340. ,  282.4,  406. ,  300. ,  374. ,  253.3,
#         195.1,  269. ,  329.3,  250.7,  345.3,  379.3,  275. ,  215.2,
#           nan,  323. ,  243. ,  364.2,  282. ,  246. ,  334.5,  250. ,
#         241. ,  280. ,  380.3,  180.1,  299. ,  223. ,  361. ,  415. ,
#         266. ,  286. ,  329.4,  400. ,  397. ,  273. ,  387.6,  298. ,
#         397.6,  380.2,  643.1,  263. ,  486. ,  238. ,  450.7,  413. ,
#         305. ,  226.4,  321. , 1376. , 1034.4,  853. ,  341. ,  131.4,
#         800.4,  873.4,  816. ,  110.4, 1500.2, 1115. ,  700. ,  953.2,
#         304. ,  563.2,  251. ,  500.4, 1729. ,  319.2,  344. ,  151.1,
#         500. ,  225.3,  234. , 1000.1,  242. ,   50.3,  600.1,  105.3,
#          50.5,  127.4,  229.4,  128.2,  244.2,  188.2,  604.1,   77.7,
#          92.7,  124. ,  800.3,   86.2,  500.3, 1860.4,  325.2,  124.2,
#         367.6,  351.7,  443. ,  277.4,  332.7,  193.9,  100.7,  336.7,
# ...

# %%
df[df['Calories']>400]
df
# Out:
#      Distance  Pulse  Maxpulse  Calories
# 0        60.0    110       130     409.1
# 1        60.0    117       145     479.0
# 2        60.0    103       135     340.0
# 3        45.0    109       175     282.4
# 4        45.0    117       148     406.0
# ..        ...    ...       ...       ...
# 164      60.0    105       140     290.8
# 165      60.0    110       145     300.0
# 166      60.0    115       145     310.2
# 167      75.0    120       150     320.4
# 168      75.0    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df['Calories'].value_counts()
# Out:
# 300.0    10
# 500.0     3
# 270.4     2
# 225.3     2
# 500.4     2
#          ..
# 413.0     1
# 450.7     1
# 238.0     1
# 486.0     1
# 330.4     1
# Name: Calories, Length: 142, dtype: int64

# %%
df[df['Calories']> 300]
# Out:
#      Distance  Pulse  Maxpulse  Calories
# 0        60.0    110       130     409.1
# 1        60.0    117       145     479.0
# 2        60.0    103       135     340.0
# 4        45.0    117       148     406.0
# 6        60.0    110       136     374.0
# ..        ...    ...       ...       ...
# 155      60.0    111       151     368.5
# 158      60.0    114       150     382.8
# 166      60.0    115       145     310.2
# 167      75.0    120       150     320.4
# 168      75.0    125       150     330.4
#
# [88 rows x 4 columns]

# %%
y = df['Calories'].mean()
print(y)
# Out:
# 375.79024390243904

# %%
#Calculate mean of calories column and replace NaN with that value
y = df["Calories"].mean()
y = round(y,1)
print(y)
#df["Calories"] = df["Calories"].replace(to_replace = nan, value = y)
#print(df.isnull().sum())
# Out:
# 375.8

# %%
x = df['Distance'].mode()
print(x)
# Out:
# 0    60.0
# Name: Distance, dtype: float64

# %%
df.isnull().sum()
# Out:
# Distance    5
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
x = df['Distance'].mean()
x = round(x,1)
print(x)
# Out:
# 64.4

# %%
x = round(65.8745,1)
print(x)
# Out:
# 65.9

# %%
print(y)
# Out:
# 375.8

# %%
y = df['Calories'].mean()
y = round(y,1)
print(y)
#df['Calories'] = df['Calories'].fillna(y)
# Out:
# 375.8

# %%
print(' ')

# %%
df['Distance'] = df['Distance'].fillna(x)

# %%
df.isnull().sum()
# Out:
# Distance    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df['Distance'].unique()
# Out:
# array([ 60. ,  45. ,  30. ,  65.9,  80. ,  20. , 210. , 160. , 180. ,
#        150. , 300. ,  90. , 120. , 270. ,  15. ,  25. ,  75. ])

# %%
from numpy import nan
df['Distance'] = df['Distance'].replace(to_replace =64.4, value=64.0)

# %%
df['Calories'] = df['Calories'].fillna(df['Calories'].mode())

# %%
df['Calories'].unique()
# Out:
# array([ 409.1,  479. ,  340. ,  282.4,  406. ,  300. ,  374. ,  253.3,
#         195.1,  269. ,  329.3,  250.7,  345.3,  379.3,  275. ,  215.2,
#           nan,  323. ,  243. ,  364.2,  282. ,  246. ,  334.5,  250. ,
#         241. ,  280. ,  380.3,  180.1,  299. ,  223. ,  361. ,  415. ,
#         266. ,  286. ,  329.4,  400. ,  397. ,  273. ,  387.6,  298. ,
#         397.6,  380.2,  643.1,  263. ,  486. ,  238. ,  450.7,  413. ,
#         305. ,  226.4,  321. , 1376. , 1034.4,  853. ,  341. ,  131.4,
#         800.4,  873.4,  816. ,  110.4, 1500.2, 1115. ,  700. ,  953.2,
#         304. ,  563.2,  251. ,  500.4, 1729. ,  319.2,  344. ,  151.1,
#         500. ,  225.3,  234. , 1000.1,  242. ,   50.3,  600.1,  105.3,
#          50.5,  127.4,  229.4,  128.2,  244.2,  188.2,  604.1,   77.7,
#          92.7,  124. ,  800.3,   86.2,  500.3, 1860.4,  325.2,  124.2,
#         367.6,  351.7,  443. ,  277.4,  332.7,  193.9,  100.7,  336.7,
# ...

# %%
df
# Out:
#      Distance  Pulse  Maxpulse  Calories
# 0        60.0    110       130     409.1
# 1        60.0    117       145     479.0
# 2        60.0    103       135     340.0
# 3        45.0    109       175     282.4
# 4        45.0    117       148     406.0
# ..        ...    ...       ...       ...
# 164      60.0    105       140     290.8
# 165      60.0    110       145     300.0
# 166      60.0    115       145     310.2
# 167      75.0    120       150     320.4
# 168      75.0    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df['PulsePlus'] = df['Maxpulse']- df['Pulse']
df
# Out:
#      Distance  Pulse  Maxpulse  Calories  PulsePlus
# 0        60.0    110       130     409.1         20
# 1        60.0    117       145     479.0         28
# 2        60.0    103       135     340.0         32
# 3        45.0    109       175     282.4         66
# 4        45.0    117       148     406.0         31
# ..        ...    ...       ...       ...        ...
# 164      60.0    105       140     290.8         35
# 165      60.0    110       145     300.0         35
# 166      60.0    115       145     310.2         30
# 167      75.0    120       150     320.4         30
# 168      75.0    125       150     330.4         25
#
# [169 rows x 5 columns]

# %%
new_df = df[['Distance','PulsePlus']]
print(new_df)
# Out:
#      Distance  PulsePlus
# 0        60.0         20
# 1        60.0         28
# 2        60.0         32
# 3        45.0         66
# 4        45.0         31
# ..        ...        ...
# 164      60.0         35
# 165      60.0         35
# 166      60.0         30
# 167      75.0         30
# 168      75.0         25
#
# [169 rows x 2 columns]

# %%
corrMat = df.corr(method='pearson')
print(corrMat)
# Out:
#            Distance     Pulse  Maxpulse  Calories  PulsePlus
# Distance   1.000000 -0.144545  0.016733  0.920091   0.230809
# Pulse     -0.144545  1.000000  0.786535  0.025121  -0.152866
# Maxpulse   0.016733  0.786535  1.000000  0.203813   0.490053
# Calories   0.920091  0.025121  0.203813  1.000000   0.289388
# PulsePlus  0.230809 -0.152866  0.490053  0.289388   1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_axis = np.array([0,10])
y_axis = np.array([0,100])

# %%
plt.plot(x_axis, y_axis)
plt.show()

# %%
x_axis = np.array([1,5])
y_axis = np.array([4, 12])
plt.plot(x_axis, y_axis, )
plt.show()

# %%
x_axis = np.array([1,3, 6, 8, 10])
y_axis = np.array([1, 5, 6,3, 12])
plt.plot(x_axis, y_axis, linestyle ='dotted', color='red')
plt.title('Exercise Readings')
plt.xlabel('Pulse')
plt.ylabel('Calories')
plt.grid()
plt.show()

# %%
#Subplot 1

x_axis = np.array([1,3, 6, 8, 10])
y_axis = np.array([1, 5, 6,3, 12])
plt.plot(x_axis, y_axis, linestyle ='dotted' )
plt.title('Exercise Readings')
plt.xlabel('Pulse')
plt.ylabel('Calories')
plt.subplot(1,1,1) # 1 row, 2 columns, select the 1st subplot
plt.grid()
plt.show()


#Subplot 2
x_axis = np.array([4,1, 6, 8, 15])
y_axis = np.array([6, 5, 6,7, 10])
plt.plot(x_axis, y_axis, linestyle ='dotted' )
plt.title('Exercise Readings')
plt.xlabel('Pulse')
plt.ylabel('Calories')
plt.subplot(1,1,1)  # 1 row, 2 columns, select the 2nd subplot
plt.grid()
plt.show()

# %%
x_axis = np.array([1,3, 6, 8, 10, 2, 10, 5, 7, 8, 3, 5])
y_axis = np.array([1, 5, 6,3, 12, 5, 5, 8, 10, 6, 3,6])
plt.scatter(x_axis, y_axis)
plt.title('Exercise Readings')
plt.xlabel('Pulse')
plt.ylabel('Calories')
plt.grid()
plt.show()

# %%
#Bar
x_axis = np.array(['Pen', 'Pencil', 'Paper', 'Marker'])
y_axis = np.array([10, 30, 10, 15])
plt.bar(x_axis, y_axis)
plt.title('Items Sales')
plt.xlabel('Item')
plt.ylabel('Quantity')
plt.show()

# %%
#History
x_axis = np.array([100, 10, 200])
plt.hist(x_axis)
plt.title('Items Sales')
plt.xlabel('Item')
plt.ylabel('Quantity')
plt.show()

# %%
df
# Out:
#      Distance  Pulse  Maxpulse  Calories  PulsePlus
# 0        60.0    110       130     409.1         20
# 1        60.0    117       145     479.0         28
# 2        60.0    103       135     340.0         32
# 3        45.0    109       175     282.4         66
# 4        45.0    117       148     406.0         31
# ..        ...    ...       ...       ...        ...
# 164      60.0    105       140     290.8         35
# 165      60.0    110       145     300.0         35
# 166      60.0    115       145     310.2         30
# 167      75.0    120       150     320.4         30
# 168      75.0    125       150     330.4         25
#
# [169 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Distance'].plot(kind='hist', bins=20, title='Distance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Pulse', y='Maxpulse', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Maxpulse'].plot(kind='hist', bins=20, title='Maxpulse')
plt.xlabel('ThinkNumbers')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Maxpulse vs Calories


df.plot(kind='scatter', x='Maxpulse', y='Calories', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Plotting
plt.figure(figsize=(10, 6))

# Scatter plot for Pulse and Maxpulse
plt.scatter(df['Distance'], df['Pulse'], label='Pulse', color='blue')
plt.scatter(df['Distance'], df['Maxpulse'], label='Maxpulse', color='red')


# Line plot for Calories
plt.plot(df['Distance'], df['Calories'], label='Calories', linestyle='--', marker='o', color='green')

# Adding labels and title
plt.xlabel('Distance')
plt.ylabel('Values')
plt.title('Fitness Dataset')
plt.legend()

# Show the plot
plt.show()

# %%
df
# Out:
#      Distance  Pulse  Maxpulse  Calories  PulsePlus
# 0        60.0    110       130     409.1         20
# 1        60.0    117       145     479.0         28
# 2        60.0    103       135     340.0         32
# 3        45.0    109       175     282.4         66
# 4        45.0    117       148     406.0         31
# ..        ...    ...       ...       ...        ...
# 164      60.0    105       140     290.8         35
# 165      60.0    110       145     300.0         35
# 166      60.0    115       145     310.2         30
# 167      75.0    120       150     320.4         30
# 168      75.0    125       150     330.4         25
#
# [169 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Distance'].plot(kind='hist', bins=20, title='Distance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df['Calories'].plot(kind='line', figsize=(8, 4), title='Calories')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.plot(kind='scatter', x='Pulse', y='Maxpulse', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#from matplotlib import pyplot as plt
df['Pulse'].plot(kind='hist', bins=50, title='Pulse')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['Pulse'].unique()
# Out:
# array([110, 117, 103, 109, 102, 104,  98, 100, 106,  90,  97, 108, 130,
#        105,  92, 101,  93, 107, 114, 111,  99, 123, 118, 136, 121, 115,
#        153, 159, 149, 151, 129,  83,  80, 150,  95, 152, 137, 124, 116,
#        112, 119, 113, 141, 122,  85, 120, 125])

# %%
df
# Out:
#      Distance  Pulse  Maxpulse  Calories  PulsePlus
# 0        60.0    110       130     409.1         20
# 1        60.0    117       145     479.0         28
# 2        60.0    103       135     340.0         32
# 3        45.0    109       175     282.4         66
# 4        45.0    117       148     406.0         31
# ..        ...    ...       ...       ...        ...
# 164      60.0    105       140     290.8         35
# 165      60.0    110       145     300.0         35
# 166      60.0    115       145     310.2         30
# 167      75.0    120       150     320.4         30
# 168      75.0    125       150     330.4         25
#
# [169 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Distance'].plot(kind='hist', bins=20, title='Distance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df['Pulse'].plot(kind='line', figsize=(8, 4), title='Pulse')
plt.gca().spines[['top', 'right']].set_visible(False)
